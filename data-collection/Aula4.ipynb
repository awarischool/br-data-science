# %% [markdown]
# ## Importando dados localmente
#
# ### Como importar CSV

# %%
import pandas as pd

# %%
df_csv = pd.read_csv('meu_arquivo.csv', index_col=0)

# %%
df_csv
# Out:
#    col1  col2  col3  col4
# 0   221   956   796   136
# 1   879   696   875   617
# 2   725   303   363   780
# 3   538   840   247   178

# %% [markdown]
# ### Como importar XLSX

# %%
df_excel = pd.read_excel('meu_arquivo.xlsx')

# %%
df_excel
# Out:
#    col1  col2  col3  col4
# 0   221   956   796   136
# 1   879   696   875   617
# 2   725   303   363   780
# 3   538   840   247   178

# %% [markdown]
# ### Como importar TXT

# %%
f = open('meu_arquivo.txt')
meu_texto = f.read()
f.close()

# %%
type(meu_texto)
# Out:
# str

# %%
with open('meu_arquivo.txt') as f:
    meu_texto = f.read()

# %% [markdown]
# ### Importar fotos

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img=mpimg.imread('meu_arquivo.jpg')

# %%
plt.imshow(img)

# %% [markdown]
# ## Importando dados da internet
#
# ### Repositorio de Arquivos

# %%
url_data = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv'

# %%
df_covid = pd.read_csv(url_data)

# %%
df_covid.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  6/5/20  6/6/20  6/7/20  6/8/20  6/9/20  \
# 0        0        0        0  ...    1762    1830    1875    2171    2651
# 1        0        0        0  ...     910     925     938     945     960
# 2        0        0        0  ...    6453    6631    6717    6799    6951
# 3        0        0        0  ...     741     741     744     751     757
# 4        0        0        0  ...      21      24      24      38      38
#
#    6/10/20  6/11/20  6/12/20  6/13/20  6/14/20
# ...

# %%
url_gsheet = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vTCpxfruR6teOmMB5bAHwMJAGaKYQ7RmQpua_JbMF_c5V4X5PY0LAgnZqTvfhSPijUxubs4XHULLiiS/pub?gid=0&single=true&output=csv'

# %%
df = pd.read_csv(url_gsheet)
# Out:
#        Nome  Telefone
# 0  Fernando     99999

# %% [markdown]
# ### Ler Imagens

# %%
from PIL import Image
import requests
from io import BytesIO

url = 'https://cdn.shortpixel.ai/client/q_glossy,ret_img,w_800/https://pet.talknmb.com.br/wp-content/uploads/2019/01/artigo_tendencias-mercado-pet-2019.jpg'
response = requests.get(url)
img = Image.open(BytesIO(response.content))

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x500 at 0x1243E8210>
